# %%
# Requirements
# %pip install dlt[lancedb]==0.5.1a0
# %pip install sentence-transformers
# Out:
# ...
#    ---------------------------------------- 0.0/707.5 kB ? eta -:--:--
#    - ------------------------------------- 30.7/707.5 kB 640.0 kB/s eta 0:00:02
#    - ------------------------------------- 30.7/707.5 kB 640.0 kB/s eta 0:00:02
#    ------ ------------------------------- 112.6/707.5 kB 819.2 kB/s eta 0:00:01
#    ------ ------------------------------- 112.6/707.5 kB 819.2 kB/s eta 0:00:01
#    --------- ---------------------------- 174.1/707.5 kB 748.1 kB/s eta 0:00:01
#    ------------ ------------------------- 235.5/707.5 kB 798.9 kB/s eta 0:00:01
#    --------------- ---------------------- 286.7/707.5 kB 840.4 kB/s eta 0:00:01
#    ------------------- ------------------ 358.4/707.5 kB 928.4 kB/s eta 0:00:01
#    --------------------- ---------------- 399.4/707.5 kB 922.1 kB/s eta 0:00:01
#    ------------------------- ------------ 471.0/707.5 kB 982.5 kB/s eta 0:00:01
#    ----------------------------- ---------- 522.2/707.5 kB 1.0 MB/s eta 0:00:01
# ...

# %%
#Initialize dlt rest_api instance
import subprocess

subprocess.run(["dlt", "init", "rest_api", "lancedb"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 #Initialize dlt rest_api instance
#       2 import subprocess
# ----> 4 subprocess.run(["dlt", "init", "rest_api", "lancedb"])
#
# File c:\Users\Daniel\AppData\Local\Programs\Python\Python310\lib\subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     498     kwargs['stdout'] = PIPE
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#     503         stdout, stderr = process.communicate(input, timeout=timeout)
#
# ...
